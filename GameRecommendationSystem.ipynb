# %% [markdown]
# # Recommendation System
# # Game Recommendation with *content-based filtering*
#
# *by: [Rifqi Novandi](https://github.com/rifqinvnd)*

# %% [markdown]
# ## Background
# In this machine learning project, a recommendation system model will be created to predict preferred games based on other games that have similar similarities or by using *content-based filtering* techniques with several variables such as platform, year of release, genre, etc.

# %% [markdown]
# ## 1. Install and import the required libraries

# %%
# Install the required library
# !pip install -U scikit-learn
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.6.15)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
# using os and zipfile library to prepare the dataset
import os
import zipfile
import json

# library for data processing
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.preprocessing import MinMaxScaler

# library to make the recommendation system model
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics.pairwise import cosine_similarity

# library for evaluate the machine learning model
from sklearn.metrics import calinski_harabasz_score, davies_bouldin_score

# %% [markdown]
# ## 2. Prepares the Dataset

# %% [markdown]
# ### 2.1 Prepare the username and kaggle key

# %%
# prepares the Kaggle credential environment
os.environ['KAGGLE_USERNAME'] = 'rifqinovandi'
os.environ['KAGGLE_KEY'] = '61655b112a6218032cc7743aab07e371'

# %% [markdown]
# ### 2.2 Download and prepare the dataset

# %%
# Download the dataset with Kaggle CLI
# !kaggle datasets download -d rush4ratio/video-game-sales-with-ratings
# Out:
# Downloading video-game-sales-with-ratings.zip to /content
#   0% 0.00/476k [00:00<?, ?B/s]
# 100% 476k/476k [00:00<00:00, 127MB/s]

# %%
# Extract zip file to CWD
files = "/content/video-game-sales-with-ratings.zip"
zip = zipfile.ZipFile(files, 'r')
zip.extractall('/content')
zip.close()

# %% [markdown]
# ## 3. Data Understanding

# %% [markdown]
# ### 3.1 Read data with pandas DataFrame

# %%
df = pd.read_csv(files)
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# ## 3.2 Memahami isi keseluruhan dataset

# %%
df.shape
# Out:
# (16719, 16)

# %%
# Check dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
# Check NaN value in columns
df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
# Describe dataset column
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# 25%        0.000000      0.060000     60.000000     12.000000     10.000000
# 50%        0.010000      0.170000     71.000000     21.000000     24.000000
# 75%        0.030000      0.470000     79.000000     36.000000     81.000000
# max       10.570000     82.530000     98.000000    113.000000  10665.000000

# %% [markdown]
# ## 4. Data Preparation

# %% [markdown]
# ### 4.1 Drop column that have missing values and unused

# %%
df.drop(['Global_Sales', 'Critic_Score', 'Critic_Count', 'User_Count'], axis=1, inplace=True)

# %% [markdown]
# ### 4.2 Clean every columns of the data

# %% [markdown]
# #### 4.2.1 Name column

# %%
# Check missing value
df[df['Name'].isna()]
# Out:
#       Name Platform  Year_of_Release Genre              Publisher  NA_Sales  \
# 659    NaN      GEN           1993.0   NaN  Acclaim Entertainment      1.78
# 14246  NaN      GEN           1993.0   NaN  Acclaim Entertainment      0.00
#
#        EU_Sales  JP_Sales  Other_Sales User_Score Developer Rating
# 659        0.53      0.00         0.08        NaN       NaN    NaN
# 14246      0.00      0.03         0.00        NaN       NaN    NaN

# %%
# Drop missing-value
for index in df[df['Name'].isna()].index:
  df.drop(index, axis=0, inplace=True)

# %%
# make sure the missing value has been deleted
if(df['Name'].isna().sum() == 0):
  print("There is no empty data in the Name column")
else:
  print("Missing value detected")
# Out:
# There is no empty data in the Name column

# %% [markdown]
# #### 4.2.2 Platform Column

# %%
# use collections Counter to check the sum of each platform column element
platform_counter = Counter(df['Platform'])
platform_counter
# Out:
# Counter({'2600': 133,
#          '3DO': 3,
#          '3DS': 520,
#          'DC': 52,
#          'DS': 2152,
#          'GB': 98,
#          'GBA': 822,
#          'GC': 556,
#          'GEN': 27,
#          'GG': 1,
#          'N64': 319,
#          'NES': 98,
#          'NG': 12,
#          'PC': 974,
#          'PCFX': 1,
#          'PS': 1197,
#          'PS2': 2161,
#          'PS3': 1331,
#          'PS4': 393,
#          'PSP': 1209,
#          'PSV': 432,
#          'SAT': 173,
#          'SCD': 6,
#          'SNES': 239,
#          'TG16': 2,
#          'WS': 6,
#          'Wii': 1320,
#          'WiiU': 147,
#          'X360': 1262,
#          'XB': 824,
#          'XOne': 247})

# %%
# removes columns with counts less than 350
platform_less_than_350 = ['2600', '3DO', 'DC', 'GB', 'GEN', 'GG', 'N64','NES', 'NG',
                          'PCFX', 'SAT', 'SCD', 'SNES', 'TG16', 'WS', 'WiiU', 'XOne']

df = df[~df['Platform'].isin(platform_less_than_350)]

# %%
# Check unique element
df['Platform'].unique()
# Out:
# array(['Wii', 'DS', 'X360', 'PS3', 'PS2', 'GBA', 'PS4', '3DS', 'PS', 'XB',
#        'PC', 'PSP', 'GC', 'PSV'], dtype=object)

# %% [markdown]
# #### 4.2.3 Genre Column

# %%
# Check missing value
df['Genre'].isna().sum()
# Out:
# 0

# %%
# Check unique element
df['Genre'].unique()
# Out:
# array(['Sports', 'Racing', 'Platform', 'Misc', 'Simulation', 'Action',
#        'Role-Playing', 'Puzzle', 'Shooter', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
# Check the sum of each unique element
genre_counter = Counter(df['Genre'])
genre_counter
# Out:
# Counter({'Action': 3082,
#          'Adventure': 1229,
#          'Fighting': 718,
#          'Misc': 1641,
#          'Platform': 738,
#          'Puzzle': 505,
#          'Racing': 1132,
#          'Role-Playing': 1359,
#          'Shooter': 1182,
#          'Simulation': 835,
#          'Sports': 2108,
#          'Strategy': 624})

# %%
# discard row with misc genre that is too complex
df = df[df['Genre'] != 'Misc']

# %%
# check dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13512 entries, 0 to 16718
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             13512 non-null  object
#  1   Platform         13512 non-null  object
#  2   Year_of_Release  13293 non-null  float64
#  3   Genre            13512 non-null  object
#  4   Publisher        13485 non-null  object
#  5   NA_Sales         13512 non-null  float64
#  6   EU_Sales         13512 non-null  float64
#  7   JP_Sales         13512 non-null  float64
#  8   Other_Sales      13512 non-null  float64
#  9   User_Score       8844 non-null   object
#  10  Developer        8925 non-null   object
#  11  Rating           8792 non-null   object
# dtypes: float64(5), object(7)
# memory usage: 1.3+ MB

# %% [markdown]
# #### 4.2.4 Publisher Column

# %%
# check missing-value
df['Publisher'].isna().sum()
# Out:
# 27

# %%
# remove every riw with missing value
for index in df[df['Publisher'].isna()].index:
  df.drop(index, axis=0, inplace=True)

# %%
# recheck every missing value in the publisher column has been removed
if(df['Publisher'].isna().sum() == 0):
  print("There is no empty data in the Publisher column")
else:
  print("Missing value detected")
# Out:
# There is no empty data in the Publisher column

# %%
# Check unique element
df['Publisher'].unique()
# Out:
# array(['Nintendo', 'Take-Two Interactive', 'Sony Computer Entertainment',
#        'Activision', 'Microsoft Game Studios', 'Bethesda Softworks',
#        'Electronic Arts', 'Sega', 'SquareSoft', '505 Games', 'Ubisoft',
#        'GT Interactive', 'Konami Digital Entertainment', 'Square Enix',
#        'Sony Computer Entertainment Europe', 'Virgin Interactive',
#        'LucasArts', 'Capcom', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'Atari',
#        'Vivendi Games', 'Enix Corporation', 'Hasbro Interactive',
#        'Namco Bandai Games', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'Disney Interactive Studios',
#        'Codemasters', 'Majesco Entertainment', 'Red Orb', 'Level 5',
#        'Midway Games', 'JVC', 'Deep Silver', 'NCSoft', '989 Studios',
#        'UEP Systems', 'Maxis', 'Tecmo Koei', 'ASCII Entertainment',
#        'Valve Software', 'Unknown', 'Valve', 'Hello Games', 'D3Publisher',
#        'Activision Value', 'Infogrames', 'Red Storm Entertainment',
#        'Global Star', 'Gotham Games', 'Westwood Studios', 'GungHo',
#        'Crave Entertainment', 'TDK Mediactive', 'ASC Games', 'Accolade',
#        'Sony Online Entertainment', '3DO', 'Natsume', 'RTL', 'Alchemist',
#        'Black Label Games', 'SouthPeak Games', 'Focus Home Interactive',
#        'Zoo Digital Publishing', 'Psygnosis', 'City Interactive',
#        'Empire Interactive', 'Success', 'Compile', 'Russel', 'Atlus',
#        'Mastertronic', 'Slightly Mad Studios', 'Taito', 'Agetec',
#        'Microprose', 'Play It', 'Tomy Corporation', 'Koch Media',
#        'Game Factory', 'Titus', 'Marvelous Entertainment', 'Genki',
#        'Mojang', 'CTO SpA', 'TalonSoft', 'Crystal Dynamics',
#        'Square Enix ', 'mixi, Inc', 'SCi', 'Rage Software',
#        'Ubisoft Annecy', 'Interplay', 'Rising Star Games',
#        'Scholastic Inc.', 'Square EA', 'Hudson Soft', 'Banpresto',
#        'Hudson Entertainment', 'Nobilis', 'Avanquest Software',
#        'Big Ben Interactive', 'Touchstone', 'Spike',
#        'Nippon Ichi Software', 'Sony Computer Entertainment America',
#        'Jester Interactive', 'Illusion Softworks', 'Metro 3D', 'GSP',
#        'Rondomedia', 'Square', 'Ghostlight',
#        'BMG Interactive Entertainment', 'PQube', 'Trion Worlds',
#        'Xseed Games', 'Ignition Entertainment', 'Kadokawa Shoten',
#        'Enterbrain', 'System 3 Arcade Software', 'Gamebridge',
#        'Midas Interactive Entertainment', 'Jaleco', 'XS Games',
#        'Rebellion', 'Activision Blizzard', 'Xplosiv', 'Wanadoo',
#        'Telltale Games', 'NovaLogic', 'BAM! Entertainment',
#        'Tetris Online', 'Mastiff', 'TYO', 'Screenlife',
#        'Knowledge Adventure', 'Pioneer LDC', 'Magical Company',
#        'Zoo Games', 'Electronic Arts Victor', 'Human Entertainment',
#        'Jack of All Games', 'Black Bean Games', '989 Sports', 'Destineer',
#        'Takara Tomy', 'ChunSoft', 'Starfish', 'Zushi Games', 'Jorudan',
#        'LEGO Media', 'Destination Software, Inc', 'New',
#        'Sammy Corporation', 'Brash Entertainment', 'Kalypso Media',
#        'Ackkstudios', 'PopCap Games', 'Gathering of Developers', 'Ocean',
#        'Marvelous Interactive', 'Avanquest', 'Storm City Games',
#        'CokeM Interactive', 'Home Entertainment Suppliers',
#        'Arc System Works', 'Mud Duck Productions', 'Wargaming.net',
#        'Playmates', 'Hamster Corporation', 'From Software',
#        'Conspiracy Entertainment', 'Mumbo Jumbo', 'DTP Entertainment',
#        'Indie Games', 'NewKidCo', 'Takara', 'Liquid Games', 'Axela',
#        'ArtDink', 'Sunsoft', 'Little Orbit', 'FuRyu', 'Gust', 'Mindscape',
#        'Nihon Falcom Corporation', 'Xing Entertainment', 'ValuSoft',
#        'Oxygen Interactive', 'American Softworks', 'Falcom Corporation',
#        'Kemco', 'Detn8 Games', 'Nordic Games', 'Milestone S.r.l.',
#        'Mattel Interactive', 'Seta Corporation', 'On Demand', 'CCP',
#        'Rebellion Developments', 'Agatsuma Entertainment', 'Aspyr',
#        'Compile Heart', 'Merscom LLC', 'JoWood Productions', 'TDK Core',
#        'Kadokawa Games', 'Nordcurrent', 'SSI', 'Media Rings',
#        'Foreign Media Games', 'Core Design Ltd.', 'bitComposer Games',
#        'Victor Interactive', 'Astragon', 'Asylum Entertainment',
#        'Performance Designed Products', 'Essential Games', 'SNK',
#        'Adeline Software', 'Funcom', 'PlayV', 'GameMill Entertainment',
#        'Panther Software', 'Blast! Entertainment Ltd',
#        'Gremlin Interactive Ltd', 'Playlogic Game Factory',
#        'Nippon Columbia', 'Popcorn Arcade', 'Aques', 'System 3',
#        'AQ Interactive', 'Vir2L Studios', 'Vatical Entertainment',
#        'Neko Entertainment', 'White Park Bay Software', 'Daedalic',
#        'The Adventure Company', 'EA Games', 'UFO Interactive', 'Acquire',
#        'Broccoli', 'General Entertainment', 'Paradox Interactive',
#        'Yacht Club Games', 'Swing! Entertainment', 'Aqua Plus',
#        'Excalibur Publishing', 'Hip Interactive', 'Tripwire Interactive',
#        'Rocket Company', 'DreamCatcher Interactive', 'SCS Software',
#        'Havas Interactive', 'Sting', 'Idea Factory', 'Telstar',
#        'U.S. Gold', 'Funsta', 'DreamWorks Interactive',
#        'Slitherine Software', 'Vic Tokai', 'MTO', 'Tru Blu Entertainment',
#        'DHM Interactive', 'Game Life', 'Crytek', 'FunSoft',
#        'Data Design Interactive', 'SPS', 'Moss', 'Telegames',
#        'NDA Productions', 'Video System', 'Bigben Interactive',
#        'Idea Factory International', 'Time Warner Interactive',
#        'Gainax Network Systems', 'SNK Playmore', 'O3 Entertainment',
#        'O-Games', 'Funbox Media', 'Xicat Interactive',
#        'Simon & Schuster Interactive', 'Syscom', 'Valcon Games',
#        'PopTop Software', 'Bohemia Interactive', 'Reef Entertainment',
#        '5pb', 'HMH Interactive', 'inXile Entertainment', 'Microids',
#        'Pinnacle', 'Avalon Interactive', 'CDV Software Entertainment',
#        'Type-Moon', 'Enjoy Gaming ltd.', 'Interplay Productions',
#        'Asmik Ace Entertainment', 'Image Epoch', 'Phantom EFX',
#        'Evolved Games', 'responDESIGN', 'Griffin International',
#        'Culture Publishers', 'Hearty Robin', 'Origin Systems',
#        'Seventh Chord', 'Abylight', 'Insomniac Games', 'Flight-Plan',
#        'Milestone', 'Aksys Games', 'Locus', 'Mad Catz',
#        'Irem Software Engineering', 'Global A Entertainment',
#        'Alternative Software', 'Mercury Games', 'Sunrise Interactive',
#        'Elite', 'Evolution Games', 'Daedalic Entertainment', 'Athena',
#        'Aria', 'Happinet', 'Altron', 'Revolution Software', 'Media Works',
#        'Gamecock', '10TACLE Studios', 'Groove Games', 'Tommo',
#        'Crimson Cow', 'Cave', 'iWin', 'Ecole',
#        'Ascaron Entertainment GmbH', 'Phenomedia', 'Grand Prix Games',
#        'DigiCube', 'Creative Core', 'Graffiti', 'WayForward Technologies',
#        'LSP Games', 'ASCII Media Works', '1C Company', 'Arika',
#        'Marvel Entertainment', 'Ertain', 'Prototype', 'Phantagram',
#        'The Learning Company', 'TechnoSoft', 'Yeti',
#        'Dusenberry Martin Racing', 'Navarre Corp', 'ESP', 'MediaQuest',
#        'Team17 Software', 'Max Five', 'Tradewest', 'Comfort',
#        'Milestone S.r.l', 'Riverhillsoft', 'Summitsoft', 'Playmore',
#        'Kool Kizz', 'Monte Christo Multimedia', 'Legacy Interactive',
#        'Cloud Imperium Games Corporation', 'Flashpoint Games',
#        'CyberFront', 'Alawar Entertainment', 'DSI Games', 'Interchannel',
#        'Hect', 'Experience Inc.', 'Iceberg Interactive', 'Ivolgamus',
#        'MC2 Entertainment', '2D Boy', 'Games Workshop', 'Kando Games',
#        'Office Create', 'Maximum Family Games', 'Gearbox Software',
#        'Princess Soft', 'Extreme Entertainment Group', 'Big Fish Games',
#        'Berkeley', 'Mamba Games', 'Fuji', 'FuRyu Corporation',
#        'Her Interactive', 'imageepoch Inc.', 'Just Flight', 'Cygames',
#        'Kaga Create', 'Introversion Software', '49Games',
#        'dramatic create', 'TGL', 'Quinrose', 'Sold Out', 'Encore',
#        'G.Rev', 'Sunflowers', 'Headup Games', 'Sweets',
#        'Kokopeli Digital Studios', 'id Software', 'Nexon', 'BushiRoad',
#        'Devolver Digital', 'Number None', 'Tryfirst', 'GN Software',
#        "Yuke's", 'Strategy First', 'Lexicon Entertainment',
#        'Kids Station', 'Licensed 4U', 'GOA', 'KID', 'King Records',
#        'Minato Station', 'Graphsim Entertainment', 'Easy Interactive',
#        'P2 Games', 'Views', 'Blue Byte', 'fonfun', 'NetRevo',
#        'Epic Games', 'Coconuts Japan', 'Phoenix Games', 'Marvelous Games',
#        'Codemasters Online', 'Aerosoft', 'Focus Multimedia',
#        'IE Institute', 'Masque Publishing', '7G//AMES',
#        'New World Computing', 'Asgard', 'Virtual Play Games',
#        'Datam Polystar', 'Culture Brain', 'HuneX', 'Visco', 'Saurus',
#        'Revolution (Japan)', 'Giza10', 'Giga', 'Mycom', 'System Soft',
#        'RED Entertainment', 'Lighthouse Interactive', 'Michaelsoft',
#        'TopWare Interactive', 'Genterprise', 'Interworks Unlimited, Inc.',
#        'Inti Creates', 'Boost On', 'Imagineer',
#        'EON Digital Entertainment', 'Nitroplus', 'Piacci',
#        'Paradox Development', 'MLB.com', 'Otomate',
#        'Ascaron Entertainment', 'Ongakukan', 'Stainless Games',
#        'UIG Entertainment', 'Takuyo', 'Interchannel-Holon',
#        'Red Flagship'], dtype=object)

# %%
# Check the unknown element
df[df['Publisher'] == 'Unknown']
# Out:
#                                                     Name Platform  \
# 944                      Gran Turismo Concept 2001 Tokyo      PS2
# 1650                                 NASCAR Thunder 2003      PS2
# 2108                                        Suikoden III      PS2
# 2224                        Teenage Mutant Ninja Turtles      GBA
# 2321                                   Blitz: The League      PS2
# ...                                                  ...      ...
# 16558     Horse Life 4: My Horse, My Friend, My Champion      3DS
# 16638  The Treasures of Mystery Island 3 Pack - Save ...       PC
# 16653                    Real Crimes: The Unicorn Killer       DS
# 16706                            STORM: Frontline Nation       PC
# 16707                                   Strawberry Nauts      PSV
#
#        Year_of_Release         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 944             2001.0        Racing   Unknown      0.00      1.10      0.42
# 1650               NaN        Racing   Unknown      0.60      0.46      0.00
# 2108               NaN  Role-Playing   Unknown      0.29      0.23      0.38
# 2224            2003.0        Action   Unknown      0.67      0.25      0.00
# 2321            2005.0        Sports   Unknown      0.74      0.03      0.00
# ...                ...           ...       ...       ...       ...       ...
# 16558           2015.0        Action   Unknown      0.00      0.01      0.00
# 16638           2011.0        Puzzle   Unknown      0.01      0.00      0.00
# 16653           2011.0        Puzzle   Unknown      0.00      0.01      0.00
# 16706           2011.0      Strategy   Unknown      0.00      0.01      0.00
# 16707           2016.0     Adventure   Unknown      0.00      0.00      0.01
#
#        Other_Sales User_Score  Developer Rating
# 944           0.33        NaN        NaN    NaN
# 1650          0.16        8.7  EA Sports      E
# 2108          0.08        7.7       KCET      T
# 2224          0.02        8.8     Konami      E
# 2321          0.12          8     Midway      M
# ...            ...        ...        ...    ...
# 16558         0.00        NaN        NaN    NaN
# 16638         0.00        NaN        NaN    NaN
# 16653         0.00        NaN        NaN    NaN
# 16706         0.00        7.2     SimBin   E10+
# 16707         0.00        NaN        NaN    NaN
#
# [168 rows x 12 columns]

# %%
# remove row with the unknown publisher
for index in df[df['Publisher'] == 'Unknown'].index:
  df.drop(index, axis=0, inplace=True)

# %% [markdown]
# #### 4.2.5 Year of Release Column

# %%
# check missing value
df['Year_of_Release'].isna().sum()
# Out:
# 115

# %%
# remove missing value
for index in df[df['Year_of_Release'].isna()].index:
  df.drop(index, axis=0, inplace=True)

# %%
# ensure the missing value has been removed
if(df['Year_of_Release'].isna().sum() == 0):
  print("There is no empty data in Year_of_Release column")
else:
  print("Missing value detected")
# Out:
# There is no empty data in Year_of_Release column

# %%
# check unique element
df['Year_of_Release'].unique()
# Out:
# array([2006., 2008., 2009., 2005., 2007., 2013., 2004., 2002., 2010.,
#        2001., 2011., 2015., 2012., 2014., 1997., 1999., 2016., 2003.,
#        1998., 1996., 2000., 1995., 1994., 1992., 2020., 2017., 1985.,
#        1988.])

# %%
# change column type to string because it is categorical
df['Year_of_Release'] = df['Year_of_Release'].astype('str')

# %%
# check missing value of the whole data
df.isna().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# User_Score         4559
# Developer          4496
# Rating             4615
# dtype: int64

# %% [markdown]
# #### 4.2.6 User Score Column

# %%
# remove the missing value in the user score, developer, and rating columns
for index in df[df['User_Score'].isna()].index:
  df.drop(index, axis=0, inplace=True)

for index in df[df['Developer'].isna()].index:
  df.drop(index, axis=0, inplace=True)

for index in df[df['Rating'].isna()].index:
  df.drop(index, axis=0, inplace=True)

# %%
# check that all missing values in the dataset have been removed
if df.isna().sum().sum() == 0:
  print('Dataset cleaned')
else:
  print('Missing value detected')
# Out:
# Dataset cleaned

# %%
# check unique element
df['User_Score'].unique()
# Out:
# array(['8', '8.3', '8.5', '8.4', '8.6', '7.7', '7.4', '8.2', '9', '8.1',
#        '8.7', '7.1', '3.4', '6.3', '5.3', '4.8', '3.2', '8.9', '6.4',
#        '7.8', '7.9', '7.5', '2.6', '7.2', '9.2', '7', '4.3', '6.6', '7.6',
#        '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '7.3', '9.4', '6.8',
#        '6.1', '6.7', '4', '5.4', '4.9', '4.5', '9.3', '4.2', '3.7', '5.8',
#        '5.6', '5.9', '3.9', '5.5', '6.2', '5.2', '6', '4.1', '4.7', '4.4',
#        '5.1', '3.5', '2.5', '3', '3.1', '2.9', '2.7', '2.2', '2', '4.6',
#        '9.5', '2.1', '3.6', '2.8', '3.3', '1.8', '3.8', '0', '1.6', '9.6',
#        '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3', '1.3',
#        '0.2', '0.5', '0.6', '1.4', '0.9', '1.9', '1', '9.7'], dtype=object)

# %%
# check tbd element in User_Score column
df[df['User_Score'] == 'tbd']
# Out:
#                                 Name Platform Year_of_Release       Genre  \
# 119                    Zumba Fitness      Wii          2010.0      Sports
# 520                  Zumba Fitness 2      Wii          2011.0      Sports
# 726        Dance Dance Revolution X2      PS2          2009.0  Simulation
# 821                  The Incredibles      GBA          2004.0      Action
# 1047                   Tetris Worlds      GBA          2001.0      Puzzle
# ...                              ...      ...             ...         ...
# 16699                Planet Monsters      GBA          2001.0      Action
# 16701               Bust-A-Move 3000       GC          2003.0      Puzzle
# 16702               Mega Brain Boost       DS          2008.0      Puzzle
# 16708                       Plushees       DS          2008.0  Simulation
# 16710  Men in Black II: Alien Escape       GC          2003.0     Shooter
#
#                           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 119                       505 Games      3.45      2.59      0.00
# 520           Majesco Entertainment      1.51      1.03      0.00
# 726    Konami Digital Entertainment      1.09      0.85      0.00
# 821                             THQ      1.15      0.77      0.04
# 1047                            THQ      1.25      0.39      0.00
# ...                             ...       ...       ...       ...
# 16699                         Titus      0.01      0.00      0.00
# 16701                       Ubisoft      0.01      0.00      0.00
# 16702         Majesco Entertainment      0.01      0.00      0.00
# 16708                     Destineer      0.01      0.00      0.00
# 16710                    Infogrames      0.01      0.00      0.00
#
#        Other_Sales User_Score                 Developer Rating
# 119           0.66        tbd  Pipeworks Software, Inc.      E
# 520           0.27        tbd    Majesco Games, Majesco      T
# 726           0.28        tbd                    Konami   E10+
# 821           0.10        tbd                    Helixe      E
# 1047          0.06        tbd                 3d6 Games      E
# ...            ...        ...                       ...    ...
# 16699         0.00        tbd        Planet Interactive      E
# 16701         0.00        tbd         Taito Corporation      E
# 16702         0.00        tbd        Interchannel-Holon      E
# 16708         0.00        tbd            Big John Games      E
# 16710         0.00        tbd                     Atari      T
#
# [1871 rows x 12 columns]

# %%
# remove row with tbd user score
for index in df[df['User_Score'] == 'tbd'].index:
  df.drop(index, axis=0, inplace=True)

# %%
# change the user score data type to float as a numerical feature
df['User_Score'] = df['User_Score'].astype('float')

# %% [markdown]
# #### 4.2.7 Developer Column

# %%
# check the number of different elements in the developer column
df['Developer'].nunique()
# Out:
# 1267

# %%
# because the number of different elements is too much and the column is categorical then the column is discarded
df.drop('Developer', axis=1, inplace=True)

# %% [markdown]
# #### 4.2.8 Rating Column

# %%
# check unique element
df['Rating'].unique()
# Out:
# array(['E', 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# ### 4.3 Duplicate data cleaning

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6662 entries, 0 to 16700
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6662 non-null   object
#  1   Platform         6662 non-null   object
#  2   Year_of_Release  6662 non-null   object
#  3   Genre            6662 non-null   object
#  4   Publisher        6662 non-null   object
#  5   NA_Sales         6662 non-null   float64
#  6   EU_Sales         6662 non-null   float64
#  7   JP_Sales         6662 non-null   float64
#  8   Other_Sales      6662 non-null   float64
#  9   User_Score       6662 non-null   float64
#  10  Rating           6662 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 624.6+ KB

# %%
# The results of the data after the cleaning process
df = df.reset_index(drop=True)
df
# Out:
#                                    Name Platform Year_of_Release     Genre  \
# 0                            Wii Sports      Wii          2006.0    Sports
# 1                        Mario Kart Wii      Wii          2008.0    Racing
# 2                     Wii Sports Resort      Wii          2009.0    Sports
# 3                 New Super Mario Bros.       DS          2006.0  Platform
# 4             New Super Mario Bros. Wii      Wii          2009.0  Platform
# ...                                 ...      ...             ...       ...
# 6657         E.T. The Extra-Terrestrial      GBA          2001.0    Action
# 6658     Mortal Kombat: Deadly Alliance      GBA          2002.0  Fighting
# 6659                            Worms 2       PC          1997.0  Strategy
# 6660  Metal Gear Solid V: Ground Zeroes       PC          2014.0    Action
# 6661                             Breach       PC          2011.0   Shooter
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                         Nintendo     41.36     28.96      3.77         8.45
# 1                         Nintendo     15.68     12.76      3.79         3.29
# 2                         Nintendo     15.61     10.93      3.28         2.95
# 3                         Nintendo     11.28      9.14      6.50         2.88
# 4                         Nintendo     14.44      6.94      4.70         2.24
# ...                            ...       ...       ...       ...          ...
# 6657                      NewKidCo      0.01      0.00      0.00         0.00
# 6658                  Midway Games      0.01      0.00      0.00         0.00
# 6659                    Microprose      0.00      0.01      0.00         0.00
# 6660  Konami Digital Entertainment      0.00      0.01      0.00         0.00
# 6661                     Destineer      0.01      0.00      0.00         0.00
#
#       User_Score Rating
# 0            8.0      E
# 1            8.3      E
# 2            8.0      E
# 3            8.5      E
# 4            8.4      E
# ...          ...    ...
# 6657         2.4      E
# 6658         8.8      M
# 6659         8.1    K-A
# 6660         7.6      M
# 6661         5.8      T
#
# [6662 rows x 11 columns]

# %%
df.describe()
# Out:
#           NA_Sales     EU_Sales     JP_Sales  Other_Sales   User_Score
# count  6662.000000  6662.000000  6662.000000  6662.000000  6662.000000
# mean      0.370982     0.224319     0.059917     0.080369     7.165596
# std       0.925752     0.666564     0.275964     0.267998     1.492732
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.060000     0.020000     0.000000     0.010000     6.500000
# 50%       0.140000     0.050000     0.000000     0.020000     7.500000
# 75%       0.370000     0.200000     0.010000     0.070000     8.200000
# max      41.360000    28.960000     6.500000    10.570000     9.700000

# %% [markdown]
# ### 4.4 Restructure data

# %% [markdown]
# #### 4.4.1 Creating a dataframe containing the game name

# %%
# save game names on new dataframe
df_game_name = pd.DataFrame({'Game': df['Name']}).reset_index(drop=True)
df_game_name.head()
# Out:
#                         Game
# 0                 Wii Sports
# 1             Mario Kart Wii
# 2          Wii Sports Resort
# 3      New Super Mario Bros.
# 4  New Super Mario Bros. Wii

# %%
# use name column as index
df.set_index('Name', inplace=True)
df.head()
# Out:
#                           Platform Year_of_Release     Genre Publisher  \
# Name
# Wii Sports                     Wii          2006.0    Sports  Nintendo
# Mario Kart Wii                 Wii          2008.0    Racing  Nintendo
# Wii Sports Resort              Wii          2009.0    Sports  Nintendo
# New Super Mario Bros.           DS          2006.0  Platform  Nintendo
# New Super Mario Bros. Wii      Wii          2009.0  Platform  Nintendo
#
#                            NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                    41.36     28.96      3.77         8.45
# Mario Kart Wii                15.68     12.76      3.79         3.29
# Wii Sports Resort             15.61     10.93      3.28         2.95
# New Super Mario Bros.         11.28      9.14      6.50         2.88
# New Super Mario Bros. Wii     14.44      6.94      4.70         2.24
#
#                            User_Score Rating
# Name
# Wii Sports                        8.0      E
# Mario Kart Wii                    8.3      E
# Wii Sports Resort                 8.0      E
# New Super Mario Bros.             8.5      E
# New Super Mario Bros. Wii         8.4      E

# %% [markdown]
# #### 4.4.2 Categorical label conversion with one-hot encoding

# %%
# select all columns with datatype object
column_object = df.dtypes[df.dtypes == 'object'].keys()
column_object
# Out:
# Index(['Platform', 'Year_of_Release', 'Genre', 'Publisher', 'Rating'], dtype='object')

# %%
# convert category data to one-hot encoding
one_hot_label = pd.get_dummies(df[column_object])
one_hot_label.head(3)
# Out:
#                    Platform_3DS  Platform_DS  Platform_GBA  Platform_GC  \
# Name
# Wii Sports                    0            0             0            0
# Mario Kart Wii                0            0             0            0
# Wii Sports Resort             0            0             0            0
#
#                    Platform_PC  Platform_PS  Platform_PS2  Platform_PS3  \
# Name
# Wii Sports                   0            0             0             0
# Mario Kart Wii               0            0             0             0
# Wii Sports Resort            0            0             0             0
#
#                    Platform_PS4  Platform_PSP  ...  Publisher_id Software  \
# Name                                           ...
# Wii Sports                    0             0  ...                      0
# Mario Kart Wii                0             0  ...                      0
# Wii Sports Resort             0             0  ...                      0
#
#                    Publisher_inXile Entertainment  Rating_AO  Rating_E  \
# Name
# Wii Sports                                      0          0         1
# Mario Kart Wii                                  0          0         1
# Wii Sports Resort                               0          0         1
#
#                    Rating_E10+  Rating_EC  Rating_K-A  Rating_M  Rating_RP  \
# Name
# Wii Sports                   0          0           0         0          0
# Mario Kart Wii               0          0           0         0          0
# Wii Sports Resort            0          0           0         0          0
#
#                    Rating_T
# Name
# Wii Sports                0
# Mario Kart Wii            0
# Wii Sports Resort         0
#
# [3 rows x 315 columns]

# %%
# delete column with data type object
df.drop(column_object,axis=1,inplace=True)
df.head()
# Out:
#                            NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                    41.36     28.96      3.77         8.45
# Mario Kart Wii                15.68     12.76      3.79         3.29
# Wii Sports Resort             15.61     10.93      3.28         2.95
# New Super Mario Bros.         11.28      9.14      6.50         2.88
# New Super Mario Bros. Wii     14.44      6.94      4.70         2.24
#
#                            User_Score
# Name
# Wii Sports                        8.0
# Mario Kart Wii                    8.3
# Wii Sports Resort                 8.0
# New Super Mario Bros.             8.5
# New Super Mario Bros. Wii         8.4

# %%
# unify one-hot encoding data with whole data
df = pd.concat([df,one_hot_label],axis=1)
df.head()
# Out:
#                            NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                    41.36     28.96      3.77         8.45
# Mario Kart Wii                15.68     12.76      3.79         3.29
# Wii Sports Resort             15.61     10.93      3.28         2.95
# New Super Mario Bros.         11.28      9.14      6.50         2.88
# New Super Mario Bros. Wii     14.44      6.94      4.70         2.24
#
#                            User_Score  Platform_3DS  Platform_DS  \
# Name
# Wii Sports                        8.0             0            0
# Mario Kart Wii                    8.3             0            0
# Wii Sports Resort                 8.0             0            0
# New Super Mario Bros.             8.5             0            1
# New Super Mario Bros. Wii         8.4             0            0
#
#                            Platform_GBA  Platform_GC  Platform_PC  ...  \
# Name                                                               ...
# Wii Sports                            0            0            0  ...
# Mario Kart Wii                        0            0            0  ...
# Wii Sports Resort                     0            0            0  ...
# New Super Mario Bros.                 0            0            0  ...
# New Super Mario Bros. Wii             0            0            0  ...
#
#                            Publisher_id Software  \
# Name
# Wii Sports                                     0
# Mario Kart Wii                                 0
# Wii Sports Resort                              0
# New Super Mario Bros.                          0
# New Super Mario Bros. Wii                      0
#
#                            Publisher_inXile Entertainment  Rating_AO  \
# Name
# Wii Sports                                              0          0
# Mario Kart Wii                                          0          0
# Wii Sports Resort                                       0          0
# New Super Mario Bros.                                   0          0
# New Super Mario Bros. Wii                               0          0
#
#                            Rating_E  Rating_E10+  Rating_EC  Rating_K-A  \
# Name
# Wii Sports                        1            0          0           0
# Mario Kart Wii                    1            0          0           0
# Wii Sports Resort                 1            0          0           0
# New Super Mario Bros.             1            0          0           0
# New Super Mario Bros. Wii         1            0          0           0
#
#                            Rating_M  Rating_RP  Rating_T
# Name
# Wii Sports                        0          0         0
# Mario Kart Wii                    0          0         0
# Wii Sports Resort                 0          0         0
# New Super Mario Bros.             0          0         0
# New Super Mario Bros. Wii         0          0         0
#
# [5 rows x 320 columns]

# %% [markdown]
# #### 4.4.3 Numerical column standardization

# %%
# select all numeric column
column_numeric = list(df.dtypes[df.dtypes == 'float64'].keys())
column_numeric
# Out:
# ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'User_Score']

# %%
# MinMaxScaler initiation
scaler = MinMaxScaler()

# %%
# numerical column data standardization
scaled = scaler.fit_transform(df[column_numeric])

# %%
# scaled the data
i=0
for column in column_numeric:
    df[column] = scaled[:,i]
    i += 1

# %%
# check the result of the normalized data
df.head()
# Out:
#                            NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                 1.000000  1.000000  0.580000     0.799432
# Mario Kart Wii             0.379110  0.440608  0.583077     0.311258
# Wii Sports Resort          0.377418  0.377417  0.504615     0.279092
# New Super Mario Bros.      0.272727  0.315608  1.000000     0.272469
# New Super Mario Bros. Wii  0.349130  0.239641  0.723077     0.211921
#
#                            User_Score  Platform_3DS  Platform_DS  \
# Name
# Wii Sports                   0.824742             0            0
# Mario Kart Wii               0.855670             0            0
# Wii Sports Resort            0.824742             0            0
# New Super Mario Bros.        0.876289             0            1
# New Super Mario Bros. Wii    0.865979             0            0
#
#                            Platform_GBA  Platform_GC  Platform_PC  ...  \
# Name                                                               ...
# Wii Sports                            0            0            0  ...
# Mario Kart Wii                        0            0            0  ...
# Wii Sports Resort                     0            0            0  ...
# New Super Mario Bros.                 0            0            0  ...
# New Super Mario Bros. Wii             0            0            0  ...
#
#                            Publisher_id Software  \
# Name
# Wii Sports                                     0
# Mario Kart Wii                                 0
# Wii Sports Resort                              0
# New Super Mario Bros.                          0
# New Super Mario Bros. Wii                      0
#
#                            Publisher_inXile Entertainment  Rating_AO  \
# Name
# Wii Sports                                              0          0
# Mario Kart Wii                                          0          0
# Wii Sports Resort                                       0          0
# New Super Mario Bros.                                   0          0
# New Super Mario Bros. Wii                               0          0
#
#                            Rating_E  Rating_E10+  Rating_EC  Rating_K-A  \
# Name
# Wii Sports                        1            0          0           0
# Mario Kart Wii                    1            0          0           0
# Wii Sports Resort                 1            0          0           0
# New Super Mario Bros.             1            0          0           0
# New Super Mario Bros. Wii         1            0          0           0
#
#                            Rating_M  Rating_RP  Rating_T
# Name
# Wii Sports                        0          0         0
# Mario Kart Wii                    0          0         0
# Wii Sports Resort                 0          0         0
# New Super Mario Bros.             0          0         0
# New Super Mario Bros. Wii         0          0         0
#
# [5 rows x 320 columns]

# %%
df.describe()
# Out:
#           NA_Sales     EU_Sales     JP_Sales  Other_Sales   User_Score  \
# count  6662.000000  6662.000000  6662.000000  6662.000000  6662.000000
# mean      0.008970     0.007746     0.009218     0.007604     0.738721
# std       0.022383     0.023017     0.042456     0.025355     0.153890
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.001451     0.000691     0.000000     0.000946     0.670103
# 50%       0.003385     0.001727     0.000000     0.001892     0.773196
# 75%       0.008946     0.006906     0.001538     0.006623     0.845361
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        Platform_3DS  Platform_DS  Platform_GBA  Platform_GC  Platform_PC  ...  \
# count   6662.000000  6662.000000   6662.000000  6662.000000  6662.000000  ...
# mean       0.023717     0.070249      0.035575     0.050886     0.104473  ...
# std        0.152176     0.255586      0.185242     0.219781     0.305896  ...
# min        0.000000     0.000000      0.000000     0.000000     0.000000  ...
# 25%        0.000000     0.000000      0.000000     0.000000     0.000000  ...
# 50%        0.000000     0.000000      0.000000     0.000000     0.000000  ...
# 75%        0.000000     0.000000      0.000000     0.000000     0.000000  ...
# max        1.000000     1.000000      1.000000     1.000000     1.000000  ...
#
#        Publisher_id Software  Publisher_inXile Entertainment    Rating_AO  \
# count            6662.000000                     6662.000000  6662.000000
# mean                0.000150                        0.000150     0.000150
# std                 0.012252                        0.012252     0.012252
# min                 0.000000                        0.000000     0.000000
# 25%                 0.000000                        0.000000     0.000000
# 50%                 0.000000                        0.000000     0.000000
# 75%                 0.000000                        0.000000     0.000000
# max                 1.000000                        1.000000     1.000000
#
#           Rating_E  Rating_E10+    Rating_EC   Rating_K-A     Rating_M  \
# count  6662.000000  6662.000000  6662.000000  6662.000000  6662.000000
# mean      0.311618     0.130742     0.000150     0.000300     0.209397
# std       0.463189     0.337143     0.012252     0.017325     0.406908
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       1.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#          Rating_RP     Rating_T
# count  6662.000000  6662.000000
# mean      0.000150     0.347493
# std       0.012252     0.476210
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     1.000000
# max       1.000000     1.000000
#
# [8 rows x 320 columns]

# %% [markdown]
# ## 5. Create *Content-based Filtering* Recommendation System Model

# %% [markdown]
# ### 5.1 Using the K-NearestNeighbors

# %%
# Model initiation
model = NearestNeighbors(metric='euclidean')

# Fit model to the data
model.fit(df)
# Out:
# NearestNeighbors(metric='euclidean')

# %%
# Create function to get the game recommendation
def GameRecommended(gamename:str, recommended_games:int=6):
  print(f'If user like playing Game: \n{gamename[0]}\n5 Game that the user might like to play:')
  # Looking for the game with the highest similarity to the game that user play
  distances, neighbors = model.kneighbors(df.loc[gamename],n_neighbors=recommended_games)
  # Input the recommended game into the list
  similar_game = []
  for gamename in df_game_name.loc[neighbors[0][:]].values:
    similar_game.append(gamename[0])
  # Input the distance score into the list
  similar_distance = []
  for distance in distances[0]:
    similar_distance.append(f"{round(100-distance, 2)}%")
  # Return a dataframe with the most recommended game
  return pd.DataFrame(data = {"Game" : similar_game[1:], "Similarity" : similar_distance[1:]})

# %%
# Give the recommendation to the selected game
GameRecommended(df_game_name.loc[111])
# Out:
# If user like playing Game:
# Final Fantasy IX
# 5 Game that the user might like to play:
#                     Game Similarity
# 0     Final Fantasy VIII     98.58%
# 1  Final Fantasy Tactics     98.57%
# 2              Xenogears     98.55%
# 3    Tales of Destiny II     98.55%
# 4           Chrono Cross     98.55%

# %% [markdown]
# ### 5.2 Using Cosine Similarity

# %%
# Calculate the cosine similarity of the dataframe
cosine_sim = cosine_similarity(df)

# Keep the result of the calculation dataframe
cosine_sim_df = pd.DataFrame(cosine_sim, index=df_game_name['Game'], columns=df_game_name['Game'])
cosine_sim_df.head(3)
# Out:
# Game               Wii Sports  Mario Kart Wii  Wii Sports Resort  \
# Game
# Wii Sports           1.000000        0.681225           0.806006
# Mario Kart Wii       0.681225        1.000000           0.686753
# Wii Sports Resort    0.806006        0.686753           1.000000
#
# Game               New Super Mario Bros.  New Super Mario Bros. Wii  \
# Game
# Wii Sports                      0.655580                   0.652319
# Mario Kart Wii                  0.541707                   0.686951
# Wii Sports Resort               0.530365                   0.838024
#
# Game               Mario Kart DS   Wii Fit  Wii Fit Plus  Grand Theft Auto V  \
# Game
# Wii Sports              0.504198  0.774904      0.769941            0.217456
# Mario Kart Wii          0.682935  0.677577      0.669040            0.180855
# Wii Sports Resort       0.520196  0.835151      0.995444            0.172429
#
# Game               Grand Theft Auto: San Andreas  ...     Trine  \
# Game                                              ...
# Wii Sports                              0.238192  ...  0.099181
# Mario Kart Wii                          0.184008  ...  0.118648
# Wii Sports Resort                       0.176879  ...  0.282934
#
# Game               Karnaaj Rally  Hospital Tycoon  Ben 10 Omniverse 2  \
# Game
# Wii Sports              0.251738         0.048428            0.064216
# Mario Kart Wii          0.455775         0.057913            0.076806
# Wii Sports Resort       0.295104         0.056737            0.075247
#
# Game               Bookworm Deluxe  E.T. The Extra-Terrestrial  \
# Game
# Wii Sports                0.382273                    0.181952
# Mario Kart Wii            0.280582                    0.211163
# Wii Sports Resort         0.280941                    0.213287
#
# Game               Mortal Kombat: Deadly Alliance   Worms 2  \
# Game
# Wii Sports                               0.105425  0.098121
# Mario Kart Wii                           0.126127  0.117379
# Wii Sports Resort                        0.123572  0.114998
#
# Game               Metal Gear Solid V: Ground Zeroes    Breach
# Game
# Wii Sports                                  0.092749  0.072453
# Mario Kart Wii                              0.110950  0.086671
# Wii Sports Resort                           0.108700  0.084915
#
# [3 rows x 6662 columns]

# %%
# Create function to get the game recommendation
def CosineGameRecommended(gamename:str, recommended_games:int=5):
  print(f'If user like playing Game: \n{gamename[0]}\n5 Game that the user might like to play:')
  # Look up the unique value of the game the user likes in the cosine sim dataframe row
  # The unique value (arr) is returned in an ordered form from small to large 
  arr, ind = np.unique(cosine_sim_df.loc[gamename[0]], return_index=True)
  # Input similar game names from the second-last index to the nth-last index
  similar_game = []
  for index in ind[-(recommended_games+1):-1]:
    similar_game.append(df_game_name.loc[index][0])
  # Input the cosine scores of similar games starting from the second-last index to the nth-last index.
  cosine_score = []
  for score in arr[-(recommended_games+1):-1]:
    cosine_score.append(score)
  # Return a dataframe with the most recommended game
  return pd.DataFrame(data = {"Game" : similar_game, "Cosine Similarity" : cosine_score}).sort_values(by='Cosine Similarity',ascending=False)

# %%
# provides recommendations with cosine similarity on selected games
CosineGameRecommended(df_game_name.loc[111])
# Out:
# If user like playing Game:
# Final Fantasy IX
# 5 Game that the user might like to play:
#                     Game  Cosine Similarity
# 4     Final Fantasy VIII           0.833562
# 3  Final Fantasy Tactics           0.825829
# 2              Xenogears           0.823134
# 1    Tales of Destiny II           0.822043
# 0           Chrono Cross           0.820439

# %% [markdown]
# ## 6. Recommendation System Model Evaluation

# %% [markdown]
# ### 6.1 Calinski Harabasz Score

# %%
calinski_harabasz_score(df, df_game_name).round(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 5.09

# %% [markdown]
# ### 6.2 Davies Bouldin Score

# %%
davies_bouldin_score(df, df_game_name).round(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2.93

# %% [markdown]
# ## Closing
# A model for game recommendation with *content-based filtering* has been completed. After testing, the model works quite well in providing the top 5 recommendations for games that users might like/play. However, there are still some shortcomings of the model as seen in the Calinski Harabasz and Davies Bouldin scores. To improve it, algorithms can be used to create other recommendation models such as using deep learning or *collaborative filtering* and then compare its performance with the current KNN model.

# %% [markdown]
# ### References
# - Scikit-learn Docummentation: [https://scikit-learn.org/stable/modules/classes.html](https://scikit-learn.org/stable/modules/classes.html)
# - Report References: [Contoh Algoritma Sistem Rekomendasi dengan Dokumentasi](https://github.com/fahmij8/ML-Exercise/blob/main/MLT-2/MLT_Proyek_Submission_2.ipynb)
# - Dataset: [Game Sales with Rating Dataset](https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings)
